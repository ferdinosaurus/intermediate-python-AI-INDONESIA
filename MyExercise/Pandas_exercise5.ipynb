# %%
import numpy as np
import pandas as pd

# %%
data_uber = pd.read_csv("dataset/My Uber Drives - 2016.csv")
data_uber
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data_uber["DISTANCE"] = np.where(data_uber["MILES*"] > 10, "Long Trip",
                            np.where(data_uber["MILES*"] < 5, "Short Trip","Medium Trip")
                        )
data_uber
# Out:
#   NaN  Medium Trip
# 616               NaN   Short Trip
# 617               NaN   Short Trip
# 618               NaN  Medium Trip
# 619               NaN  Medium Trip
# 620           Meeting  Medium Trip
# 621               NaN   Short Trip
# 622               NaN   Short Trip
# 623               NaN   Short Trip
# 624               NaN   Short Trip
# 625               NaN   Short Trip
# 626               NaN   Short Trip
# 627               NaN   Short Trip
# 628               NaN   Short Trip
# 629               NaN   Short Trip
# 630               NaN  Medium Trip
# 631               NaN  Medium Trip
# 632               NaN   Short Trip
# 633    Customer Visit   Short Trip
# 634               NaN   Short Trip
# 635    Meal/Entertain   Short Trip
# 636               NaN  Medium Trip
# 637               NaN   Short Trip
# 638    Customer Visit   Short Trip
# 639               NaN   Short Trip
# 640    Customer Visit   Short Trip
# 641               NaN  Medium Trip
# ...
